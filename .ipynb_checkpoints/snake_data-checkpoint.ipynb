# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from predata import *

# %%
len(DIRECTIONS_DATA)
# Out:
# 7829

# %%
from sklearn import preprocessing

# %%
directions_array = np.asarray(DIRECTIONS_DATA)

# %%
df = pd.DataFrame(DIRECTIONS_DATA)
df.head()
# Out:
#    0  1  2  3         4  5  6
# 0  3  0  5  1  2.236068  0  0
# 1  4  0  5  1  1.414214  0  0
# 2  5  0  5  1  1.000000  0  0
# 3  6  0  5  1  1.414214  0  0
# 4  7  0  5  1  2.236068  0  0

# %%
df.describe()
# Out:
#                  0            1            2            3            4  \
# count  7829.000000  7829.000000  7829.000000  7829.000000  7829.000000
# mean      9.805339     9.586026     9.731383     9.986716     7.174997
# std       4.919424     4.986944     5.780167     5.564834     4.451643
# min       0.000000     0.000000     1.000000     1.000000     1.000000
# 25%       6.000000     6.000000     5.000000     5.000000     3.605551
# 50%      10.000000     9.000000     9.000000     9.000000     6.403124
# 75%      14.000000    14.000000    15.000000    15.000000    10.000000
# max      19.000000    19.000000    19.000000    19.000000    24.839485
#
#                  5            6
# count  7829.000000  7829.000000
# mean     20.375655     1.447694
# std      15.901741     1.132950
# min       0.000000     0.000000
# 25%       7.000000     0.000000
# 50%      17.000000     1.000000
# 75%      31.000000     2.000000
# max      67.000000     3.000000

# %%
df2 = df.copy()

# %%
df2.drop([6], axis=1, inplace=True)

# %%
xis = df2.values

# %%
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(xis)
df3 = pd.DataFrame(x_scaled)

# %%
df3.head()
# Out:
#           0    1         2    3         4    5
# 0  0.157895  0.0  0.222222  0.0  0.051850  0.0
# 1  0.210526  0.0  0.222222  0.0  0.017375  0.0
# 2  0.263158  0.0  0.222222  0.0  0.000000  0.0
# 3  0.315789  0.0  0.222222  0.0  0.017375  0.0
# 4  0.368421  0.0  0.222222  0.0  0.051850  0.0

# %%
df3[6] = df[6]

# %%
df3.describe()
# Out:
#                  0            1            2            3            4  \
# count  7829.000000  7829.000000  7829.000000  7829.000000  7829.000000
# mean      0.516070     0.504528     0.485077     0.499262     0.259024
# std       0.258917     0.262471     0.321120     0.309157     0.186734
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.315789     0.315789     0.222222     0.222222     0.109296
# 50%       0.526316     0.473684     0.444444     0.444444     0.226646
# 75%       0.736842     0.736842     0.777778     0.777778     0.377525
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                  5            6
# count  7829.000000  7829.000000
# mean      0.304114     1.447694
# std       0.237339     1.132950
# min       0.000000     0.000000
# 25%       0.104478     0.000000
# 50%       0.253731     1.000000
# 75%       0.462687     2.000000
# max       1.000000     3.000000

# %%
data_result = df3.reset_index().values.tolist()

# %%
data_result
# Out:
# [[0.0,
#   0.15789473684210525,
#   0.0,
#   0.22222222222222224,
#   0.0,
#   0.051849609721991256,
#   0.0,
#   0.0],
#  [1.0,
#   0.21052631578947367,
#   0.0,
#   0.22222222222222224,
#   0.0,
#   0.017375105529424104,
#   0.0,
#   0.0],
#  [2.0, 0.2631578947368421, 0.0, 0.22222222222222224, 0.0, 0.0, 0.0, 0.0],
#  [3.0,
#   0.3157894736842105,
#   0.0,
#   0.22222222222222224,
#   0.0,
#   0.017375105529424104,
#   0.0,
#   0.0],
#  [4.0,
#   0.3684210526315789,
#   0.0,
#   0.22222222222222224,
#   0.0,
#   0.051849609721991256,
#   0.0,
#   0.0],
#  [5.0,
#   0.3684210526315789,
#   0.05263157894736842,
#   0.22222222222222224,
#   0.0,
#   0.04194721541679942,
#   0.0,
#   3.0],
#  [6.0,
#   0.3684210526315789,
#   0.10526315789473684,
#   0.22222222222222224,
#   0.0,
#   0.051849609721991256,
#   0.0,
#   3.0],
#  [7.0,
#   0.3684210526315789,
#   0.15789473684210525,
#   0.22222222222222224,
#   0.0,
#   0.07669742647564762,
#   0.0,
#   3.0],
#  [8.0,
# ...

# %%
thefile = open('test.txt', 'w')
for item in data_result:
  thefile.write(str(item)+', ')
